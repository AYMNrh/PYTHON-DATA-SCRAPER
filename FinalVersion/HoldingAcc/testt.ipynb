# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# import HoldinAcc as df

df = pd.read_csv('HoldingAcc.csv')
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
# how many account types are there?
df['Account Type'].unique()
# Out:
# array(['Aircraft Operator Account', 'Operator Holding Account'],
#       dtype=object)

# %%
# number of lines
df.shape[0]
# Out:
# 16427

# %%
# remove empty rows
df = df.dropna()
df.shape[0]
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
